# %% [markdown]
# # 0. 드라이브 - 코랩 연결

# %%
from google.colab import drive
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
# !pip install openai

# %% [markdown]
# # 1. API 키 설정

# %%
from dotenv import load_dotenv
load_dotenv("/content/drive/MyDrive/DILAB/YB/GPT_FineTuning/GPT-3.5-turbo/.env")
import os

api_key = os.getenv("OPENAI_API_KEY")
print("API 키 로딩 성공:", bool(api_key))
# Out:
# API 키 로딩 성공: True

# %% [markdown]
# # 2. 데이터 업로드

# %%
# !openai tools fine_tunes.prepare_data -f /content/drive/MyDrive/DILAB/YB/GPT_FineTuning/GPT-3.5-turbo/finetune_data.jsonl
# 예전 모델에서는 prompt/completion 형식이 필요했지만, chat모델에서는 messages 배열이 필요하기에 ERROR가 정상이다.
# Out:
# Analyzing...
#
# - Your file contains 1231 prompt-completion pairs
#
# ERROR in necessary_column validator: `prompt` column/key is missing. Please make sure you name your columns/keys appropriately, then retry
#
# Aborting...

# %%
# !openai api files.create -f "/content/drive/MyDrive/DILAB/YB/GPT_FineTuning/GPT-3.5-turbo/finetune_data.jsonl" -p fine-tune
# Out:
# Upload progress: 100% 4.01M/4.01M [00:00<00:00, 8.16Mit/s]
# {
#   "id": "file-SkC8SUY7eaEyKfU9ExCeAe",
#   "bytes": 4007192,
#   "created_at": 1757079486,
#   "filename": "/content/drive/MyDrive/DILAB/YB/GPT_FineTuning/GPT-3.5-turbo/finetune_data.jsonl",
#   "object": "file",
#   "purpose": "fine-tune",
#   "status": "processed",
#   "expires_at": null,
#   "status_details": null
# }

# %% [markdown]
# # 3. 파인튜닝 실행

# %%
# !openai api fine_tuning.jobs.create -m "gpt-3.5-turbo" -F file-SkC8SUY7eaEyKfU9ExCeAe
# Out:
# Error: Error code: 400 - {'error': {'message': 'You exceeded your current quota, please check your plan and billing details.', 'type': 'invalid_request_error', 'param': None, 'code': 'exceeded_quota'}}
